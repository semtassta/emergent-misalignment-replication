# %%
# !git clone https://github.com/emergent-misalignment/emergent-misalignment

# %%
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install vllm
# !pip install backoff

# %%
# !python /content/emergent-misalignment/open_models/training.py /content/emergent-misalignment/open_models/train.json

# %%
# !pip install fire

# %%
# !python /content/emergent-misalignment/open_models/eval.py --model tasya-tasya/fine-tuning-misalign --questions /content/emergent-misalignment/evaluation/first_plot_questions.yaml
